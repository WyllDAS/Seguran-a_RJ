# %% [markdown]
# # Análise de Dados abertos - Incidencia de Roubos DATARio
# ##Dados disponível em: https://www.data.rio/documents/PCRJ::incid%C3%AAncias-de-roubos-por-m%C3%AAs-total-diferen%C3%A7as-com-rela%C3%A7%C3%A3o-ao-ano-anterior-popula%C3%A7%C3%A3o-e-taxa-por-cem-mil-habitantes-segundo-o-ano-no-munic%C3%ADpio-do-rio-de-janeiro-entre-janeiro-2003-outubro-2023/about

# %%
#Importações
import pandas as pd
import numpy as np
import datetime as dt
import seaborn as sns
import statsmodels.api as sm
from matplotlib import pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.metrics import mean_squared_error,mean_absolute_error

# %%
##Analisar correlação
correlação = Dados_df.corr()
display(correlação)
# Out:
#             Ano     Valor
# Ano    1.000000  0.119913
# Valor  0.119913  1.000000

# %%
#ler o arquivo
Dados = pd.read_csv("Dados.csv")
#Agrupar por ano e valor
Dados0 = Dados.groupby('Ano')['Valor'].sum()  
#criar novo df
Dados_df = pd.DataFrame({'Ano': Dados0.index, 'Valor': Dados0.values})
#excluir o ano 2023 que está incompleto
Dados_df = Dados_df.drop(Dados_df.index[-1])
#histograma com total de incidencia de roubos
sns.histplot(data = Dados_df, x = "Valor", kde = True, label = 'Total Incidencia de Roubos')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(20,8))
sns.barplot(data = Dados_df, x ="Ano", y = "Valor")
plt.xticks(rotation=45)
plt.show()

# %%
#criar gráfico de dispersão
plt.figure(figsize=(20,8))
plt.scatter(x = Dados_df['Ano'], y = Dados_df['Valor'])

# %% [raw]
# observa-se o total de incidencias em roubos por anos, sendo que os anos que marcaram maiores registros tiveram cerca de 120 mil registros,aparentemente não encontramos uma relação linear entre as duas veriaveis, de toda forma, vamos aos testes:

# %% [markdown]
# # Regressão Linear Simples

# %%
#definindo valores
x = Dados_df['Ano'].values.reshape(-1,1)
y = Dados_df['Valor'].values
#treianndo o modelo
modeloReg = LinearRegression()
modeloReg.fit(x,y)
# Out:
# LinearRegression()

# %%
x = Dados_df['Ano']
y = Dados_df['Valor']
x = sm.add_constant(x)
modelostat = sm.OLS(y,x)
result = modelostat.fit()
print(result.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Valor   R-squared:                       0.014
# Model:                            OLS   Adj. R-squared:                 -0.040
# Method:                 Least Squares   F-statistic:                    0.2626
# Date:                Fri, 15 Dec 2023   Prob (F-statistic):              0.615
# Time:                        12:21:48   Log-Likelihood:                -224.97
# No. Observations:                  20   AIC:                             453.9
# Df Residuals:                      18   BIC:                             455.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -7.015e+05   1.53e+06     -0.459      0.652   -3.91e+06    2.51e+06
# Ano          389.0015    759.106      0.512      0.615   -1205.820    1983.823
# ==============================================================================
# Omnibus:                        1.559   Durbin-Watson:                   0.498
# Prob(Omnibus):                  0.459   Jarque-Bera (JB):                1.198
# Skew:                           0.571   Prob(JB):                        0.549
# Kurtosis:                       2.631   Cond. No.                     7.02e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.02e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
a_coeff = modeloReg.coef_
l_coeff = modeloReg.intercept_
print(f'Coeficiente Angular {a_coeff}')
print(f'Coeficiente Linear {l_coeff}')
# Out:
# Coeficiente Angular [389.00150376]
# Coeficiente Linear -701451.3263157897

# %%
plt.scatter(x = Dados1['Ano'], y = Dados1['Valor'])
plt.plot(x, l_coeff + a_coeff*x, color = 'red')
plt.show()

# %% [markdown]
# ## Regressão Polinominal

# %%
x = Dados1['Ano'].values.reshape(-1,1)
y = Dados1['Valor'].values

# %%
#grau 1
carac3 = PolynomialFeatures(degree=3)
x_Polinomio3 = carac3.fit_transform(x)

# %%
modelo3 = LinearRegression()
modelo3.fit(x_Polinomio3,y)
y_Poiinomio3 = modelo3.predict(x_Polinomio3)

# %%
plt.figure(figsize=(20,8))
plt.scatter(x,y,label = 'Y(x)');
plt.plot(x,y_Poiinomio3,color='red', label="ajuste");
plt.xlabel('Ano');
plt.ylabel('incidencia de Roubo');
plt.show()

# %%
#grau 5
carac4 = PolynomialFeatures(degree=90)
x_Polinomio4 = carac4.fit_transform(x)
modelo4 = LinearRegression()
modelo4.fit(x_Polinomio4,y)
y_Poiinomio4 = modelo4.predict(x_Polinomio4)
plt.figure(figsize=(20,8))
plt.scatter(x,y,label = 'Y(x)');
plt.plot(x,y_Poiinomio4,color='red', label="ajuste");
plt.xlabel('Ano');
plt.ylabel('incidencia de Roubo');
plt.show()

# %%
#grau 7
carac7 = PolynomialFeatures(degree=7)
x_Polinomio7 = carac7.fit_transform(x)
modelo7 = LinearRegression()
modelo7.fit(x_Polinomio7,y)
y_Poiinomio7 = modelo7.predict(x_Polinomio7)
plt.figure(figsize=(20,8))
plt.scatter(x,y,label = 'Y(x)');
plt.plot(x,y_Poiinomio7,color='red', label="ajuste");
plt.xlabel('Ano');
plt.ylabel('incidencia de Roubo');
plt.show()

# %%
#verificar erros:
MAE3 = mean_absolute_error(y,y_Poiinomio3)
MAE4 = mean_absolute_error(y,y_Poiinomio4)
MAE7 = mean_absolute_error(y,y_Poiinomio7)

print("MAE (grau=3) = {:0.4f}".format(MAE3))
print("MAE (grau=5) = {:0.4f}".format(MAE4))
print("MAE (grau=7) = {:0.4f}".format(MAE7))
# Out:
# MAE (grau=3) = 13557.3787
# MAE (grau=5) = 12828.0740
# MAE (grau=7) = 13510.0995
